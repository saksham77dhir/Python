# %%
import math

# %%
print(math.factorial(5))
# Out:
# 120

# %%
print(math.gcd(2,5,7))
print(math.lcm(12,30,15))
print(math.sin(1))
print(math.tan(0))
# Out:
# 1
# 60
# 0.8414709848078965
# 0.0

# %%
from random import random,randint,choice,shuffle

# %%
import random

# %%
print("give random value b/w 0 and 1:",random.random())
print("give random value b/w given range:",random.randint(2,100))
print("choose a number from list:",random.choice([2,3,5,7,8]))
name=['John','Jack','Jane','Jill']
shuffle(name)
print("Shuffled list:",name)
# Out:
# give random value b/w 0 and 1: 0.9843476664074167
# give random value b/w given range: 29
# choose a number from list: 8
# Shuffled list: ['Jane', 'Jill', 'Jack', 'John']

# %%
from datetime import datetime as dt

# %%
print("current date and time:",dt.now())
# Out:
# current date and time: 2025-07-05 18:08:16.051017

# %%
print("current year:",dt.now().year)
print("current month:",dt.now().month)
print("current minute:",dt.now().minute)
print("current weekday:",dt.now().weekday())
# Out:
# current year: 2025
# current month: 7
# current minute: 16
# current weekday: 5
