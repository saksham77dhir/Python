# %%
import os

# %%
print('Current working directory is:',os.getcwd())
# Out:
# Current working directory is: c:\Users\DELL\Desktop\Python

# %%
files=os.listdir()
print('Files in current working directory:',files)
# Out:
# Files in current working directory: ['.git', 'dictionary.ipynb', 'file.handling.ipynb', 'functions.ipynb', 'intro.ipynb', 'libraries.ipynb', 'set.ipynb', 'strings.ipynb']

# %%
files=os.listdir(r"C:\Users\DELL\Desktop\Python")
print('Files in current working directory:',files)
# Out:
# Files in current working directory: ['.git', 'dictionary.ipynb', 'file.handling.ipynb', 'functions.ipynb', 'intro.ipynb', 'libraries.ipynb', 'set.ipynb', 'strings.ipynb']

# %%
total_files=0
for path, folders, files in os.walk(r"C:\Users\DELL\Desktop\Python"):
    print('=>',path)
    print('folders',folders)
    print('files=',files)
    total_files+=len(files)
print('total files in directory tree:',total_files)
# Out:
# => C:\Users\DELL\Desktop\Python
# folders ['.git']
# files= ['dictionary.ipynb', 'file.handling.ipynb', 'functions.ipynb', 'intro.ipynb', 'libraries.ipynb', 'set.ipynb', 'strings.ipynb']
# => C:\Users\DELL\Desktop\Python\.git
# folders ['hooks', 'info', 'objects', 'refs']
# files= ['config', 'description', 'HEAD', 'index']
# => C:\Users\DELL\Desktop\Python\.git\hooks
# folders []
# files= ['applypatch-msg.sample', 'commit-msg.sample', 'fsmonitor-watchman.sample', 'post-update.sample', 'pre-applypatch.sample', 'pre-commit.sample', 'pre-merge-commit.sample', 'pre-push.sample', 'pre-rebase.sample', 'pre-receive.sample', 'prepare-commit-msg.sample', 'push-to-checkout.sample', 'sendemail-validate.sample', 'update.sample']
# => C:\Users\DELL\Desktop\Python\.git\info
# folders []
# files= ['exclude']
# => C:\Users\DELL\Desktop\Python\.git\objects
# folders ['09', '1c', '42', 'd8', 'info', 'pack']
# files= []
# => C:\Users\DELL\Desktop\Python\.git\objects\09
# folders []
# ...

# %%
files=r'C:\Users\DELL\Desktop\Python'
if os.path.exists(files): #.exists=checks if file exists in syste or not
    print('the file exists')
else:
    print("the file doesn't exists")
# Out:
# the file exists
