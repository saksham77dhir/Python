# %%
a=int(input('enter 1st no'))
b=int(input('enter 2nd no'))
c=int(input('enter 3rd no'))
sum=a+b+c
print(sum)
# Out:
# 6

# %%
for i in range(532,840):
    if i%3==0 and i%5==0:
        print(i)
# Out:
# 540
# 555
# 570
# 585
# 600
# 615
# 630
# 645
# 660
# 675
# 690
# 705
# 720
# 735
# 750
# 765
# 780
# 795
# 810
# 825
