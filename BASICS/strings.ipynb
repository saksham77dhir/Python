# %%
name="my name is alice"
print(str)
# Out:
# my name is alice

# %%
for i in name:
    print(i,end='')
# Out:
# my name is alice

# %%
print(name[11]) #indexing
# Out:
# a

# %%
print(name[11:16])  #slicing
print(name[11:])
# Out:
# alice
# alice

# %%
#stringDuplication
a='hi'
print(a*5)
# Out:
# hihihihihi

# %%
word='beautiful'
word.upper()
# Out:
# 'BEAUTIFUL'

# %%
word.lower()
# Out:
# 'beautiful'

# %%
word.capitalize()
# Out:
# 'Beautiful'

# %%
poem='Johny Johny yes papa eating sugar no papa telling a lie no papa open your mouth haha'
print(poem)
# Out:
# Johny Johny yes papa eating sugar no papa telling a lie no papa open your mouth haha

# %%
poem.find('papa')
# Out:
# 16

# %%
p=poem.replace('papa','fufa').replace('sugar','poison')
print(p)
# Out:
# Johny Johny yes fufa eating poison no fufa telling a lie no fufa open your mouth haha

# %%
name.split()
# Out:
# ['my', 'name', 'is', 'alice']

# %%
p.splitlines()
# Out:
# ['Johny Johny yes fufa eating poison no fufa telling a lie no fufa open your mouth haha']
