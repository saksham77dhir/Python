# %%
import pandas as pd   #for data analysis
import numpy as np
import seaborn as sns

# %% [markdown]
# -creating dataset
#    -dictionary of items
#    -list of dictionary
#    -importing csv xlsx and json files
# -Basic insights of data
# -Selection of data
#   -row wise selection
#   -column wise selection
# -cleaning and manipulating data

# %%
movies={
    'title' : ['DDLJ','RRR','PK','YJHD','SOTY'],
    'rating': [5.0,4.5,3.5,4.8,4.5],
    'year' :  [1980,2022,2023,2020,2021]
}
pd.DataFrame(movies)
# Out:
#   title  rating  year
# 0  DDLJ     5.0  1980
# 1   RRR     4.5  2022
# 2    PK     3.5  2023
# 3  YJHD     4.8  2020
# 4  SOTY     4.5  2021

# %%
movies=[
    {'title':'Inception','year':2010,'rating':8.8,'genre':'Sci-Fi'},
    {'title':'The Matrix','year':1995,'rating':8.7,'genre':'Sci-Fi'},
    {'title':'Interstellar','year':2014,'rating':8.6,'genre':'Sci-Fi'},
]
df=pd.DataFrame(movies)
df
# Out:
#           title  year  rating   genre
# 0     Inception  2010     8.8  Sci-Fi
# 1    The Matrix  1995     8.7  Sci-Fi
# 2  Interstellar  2014     8.6  Sci-Fi

# %%
df=pd.read_csv('kc_house_data.csv')
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.head(10)  #takes default as 5 rows of the DataFrame
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
df.tail(10)   #takes default as 5 rows from last
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 21603  7852140040  20140825T000000   507250.0         3       2.50
# 21604  9834201367  20150126T000000   429000.0         3       2.00
# 21605  3448900210  20141014T000000   610685.0         4       2.50
# 21606  7936000429  20150326T000000  1007500.0         4       3.50
# 21607  2997800021  20150219T000000   475000.0         3       2.50
# 21608   263000018  20140521T000000   360000.0         3       2.50
# 21609  6600060120  20150223T000000   400000.0         4       2.50
# 21610  1523300141  20140623T000000   402101.0         2       0.75
# 21611   291310100  20150116T000000   400000.0         3       2.50
# 21612  1523300157  20141015T000000   325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21603         2270      5536     2.0           0     0  ...      8
# 21604         1490      1126     3.0           0     0  ...      8
# ...

# %%
df.sample(5) #randomly prints any row
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 4366   5422560930  20150316T000000  453000.0         3       2.50
# 18181  3291800120  20150102T000000  262500.0         3       1.00
# 21385  6600060150  20150312T000000  392000.0         4       2.50
# 1038   5104511040  20150220T000000  380000.0         4       2.50
# 3825   2916600110  20150430T000000  214946.0         3       1.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 4366          1750      3900     2.0           0     0  ...      8
# 18181          970      7854     1.0           0     0  ...      7
# 21385         2130      4028     2.0           0     0  ...      8
# 1038          2000      6921     2.0           0     0  ...      8
# 3825          1290      8688     1.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 4366         1750              0      1977             0    98052  47.6638
# ...

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.info()    #null=nan  , display dataFrame summary information in concise format
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe()   #get summary statistics for numerical columns
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['id',
#  'date',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %% [markdown]
# -Row wise selection
#    -iloc() - index based selection
#    -loc() - label based selection
# -Column wise selection
#    -single column selection
#      -dictionary like selection
#      -object like selection
#
#    -multiple column selection
#      -dictionary like selection

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.iloc[21608]
# Out:
# id                     263000018
# date             20140521T000000
# price                   360000.0
# bedrooms                       3
# bathrooms                    2.5
# sqft_living                 1530
# sqft_lot                    1131
# floors                       3.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          8
# sqft_above                  1530
# sqft_basement                  0
# yr_built                    2009
# yr_renovated                   0
# zipcode                    98103
# lat                      47.6993
# long                    -122.346
# sqft_living15               1530
# sqft_lot15                  1509
# Name: 21608, dtype: object

# %%
df.iloc[-3]
# Out:
# id                    1523300141
# date             20140623T000000
# price                   402101.0
# bedrooms                       2
# bathrooms                   0.75
# sqft_living                 1020
# sqft_lot                    1350
# floors                       2.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          7
# sqft_above                  1020
# sqft_basement                  0
# yr_built                    2009
# yr_renovated                   0
# zipcode                    98144
# lat                      47.5944
# long                    -122.299
# sqft_living15               1020
# sqft_lot15                  2007
# Name: 21610, dtype: object

# %%
df.iloc[2:8]
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
# 5    101930     1.0           0     0  ...     11        3890           1530
# ...

# %%
df.iloc[[2,7,9,11]]
# Out:
#             id             date     price  bedrooms  bathrooms  sqft_living  \
# 2   5631500400  20150225T000000  180000.0         2        1.0          770
# 7   2008000270  20150115T000000  291850.0         3        1.5         1060
# 9   3793500160  20150312T000000  323000.0         3        2.5         1890
# 11  9212900260  20140527T000000  468000.0         2        1.0         1160
#
#     sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 2      10000     1.0           0     0  ...      6         770              0
# 7       9711     1.0           0     0  ...      7        1060              0
# 9       6560     2.0           0     0  ...      7        1890              0
# 11      6000     1.0           0     0  ...      7         860            300
#
#     yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 2       1933             0    98028  47.7379 -122.233           2720
# ...

# %%
df.iloc[[3,4,5],[0,1]] #select specific rows and columns by index
# Out:
#            id             date
# 3  2487200875  20141209T000000
# 4  1954400510  20150218T000000
# 5  7237550310  20140512T000000

# %%
df=df.set_index('id') #set 'id' column as the index of the dataFrame
df
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
# ...                     ...       ...       ...        ...          ...
# 263000018   20140521T000000  360000.0         3       2.50         1530
# 6600060120  20150223T000000  400000.0         4       2.50         2310
# 1523300141  20140623T000000  402101.0         2       0.75         1020
# 291310100   20150116T000000  400000.0         3       2.50         1600
# 1523300157  20141015T000000  325000.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...

# %%
df.loc[7129300520]
# Out:
# date             20141013T000000
# price                   221900.0
# bedrooms                       3
# bathrooms                    1.0
# sqft_living                 1180
# sqft_lot                    5650
# floors                       1.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          7
# sqft_above                  1180
# sqft_basement                  0
# yr_built                    1955
# yr_renovated                   0
# zipcode                    98178
# lat                      47.5112
# long                    -122.257
# sqft_living15               1340
# sqft_lot15                  5650
# Name: 7129300520, dtype: object

# %%
df.loc[263000018:1523300157] #last index inclusive in loc
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 263000018   20140521T000000  360000.0         3       2.50         1530
# 6600060120  20150223T000000  400000.0         4       2.50         2310
# 1523300141  20140623T000000  402101.0         2       0.75         1020
# 291310100   20150116T000000  400000.0         3       2.50         1600
# 1523300157  20141015T000000  325000.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 263000018       1131     3.0           0     0          3      8        1530
# 6600060120      5813     2.0           0     0          3      8        2310
# 1523300141      1350     2.0           0     0          3      7        1020
# 291310100       2388     2.0           0     0          3      8        1600
# 1523300157      1076     2.0           0     0          3      7        1020
#
# ...

# %%
df.loc[[263000018,1523300157]]
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 263000018   20140521T000000  360000.0         3       2.50         1530
# 1523300157  20141015T000000  325000.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 263000018       1131     3.0           0     0          3      8        1530
# 1523300157      1076     2.0           0     0          3      7        1020
#
#             sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# id
# 263000018               0      2009             0    98103  47.6993 -122.346
# 1523300157              0      2008             0    98144  47.5941 -122.299
#
#             sqft_living15  sqft_lot15
# id
# 263000018            1530        1509
# 1523300157           1020        1357

# %%
#column wise selection
df['price']   #select a single column by name
# Out:
# id
# 7129300520    221900.0
# 6414100192    538000.0
# 5631500400    180000.0
# 2487200875    604000.0
# 1954400510    510000.0
#                 ...
# 263000018     360000.0
# 6600060120    400000.0
# 1523300141    402101.0
# 291310100     400000.0
# 1523300157    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
df.bedrooms   #alternative syntax
# Out:
# id
# 7129300520    3
# 6414100192    3
# 5631500400    2
# 2487200875    4
# 1954400510    3
#              ..
# 263000018     3
# 6600060120    4
# 1523300141    2
# 291310100     3
# 1523300157    2
# Name: bedrooms, Length: 21613, dtype: int64

# %%
df[['bedrooms','bathrooms','price']]  #select multiple columns by name
# Out:
#             bedrooms  bathrooms     price
# id
# 7129300520         3       1.00  221900.0
# 6414100192         3       2.25  538000.0
# 5631500400         2       1.00  180000.0
# 2487200875         4       3.00  604000.0
# 1954400510         3       2.00  510000.0
# ...              ...        ...       ...
# 263000018          3       2.50  360000.0
# 6600060120         4       2.50  400000.0
# 1523300141         2       0.75  402101.0
# 291310100          3       2.50  400000.0
# 1523300157         2       0.75  325000.0
#
# [21613 rows x 3 columns]

# %% [markdown]
# DATA MANIPULATION
# - to remove columns and rows
# - to rename columns
# - to delete missing values
# - to handle missing values
# - to change the datatype of a column
# - to count the categorical data

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
cols_to_drop=['sqft_living15','sqft_lot15']
df=df.drop(columns=cols_to_drop)

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long'],
#       dtype='object')

# %%
df=df.drop(labels=[7129300520])
df
# Out:
#                        date      price  bedrooms  bathrooms  sqft_living  \
# id
# 6414100192  20141209T000000   538000.0         3       2.25         2570
# 5631500400  20150225T000000   180000.0         2       1.00          770
# 2487200875  20141209T000000   604000.0         4       3.00         1960
# 1954400510  20150218T000000   510000.0         3       2.00         1680
# 7237550310  20140512T000000  1225000.0         4       4.50         5420
# ...                     ...        ...       ...        ...          ...
# 263000018   20140521T000000   360000.0         3       2.50         1530
# 6600060120  20150223T000000   400000.0         4       2.50         2310
# 1523300141  20140623T000000   402101.0         2       0.75         1020
# 291310100   20150116T000000   400000.0         3       2.50         1600
# 1523300157  20141015T000000   325000.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...

# %%
col_rename={
    'lat':'latitude',
    'long':'longitude'
}
df=df.rename(columns=col_rename) #rename columns using a dictionary

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'latitude',
#        'longitude'],
#       dtype='object')

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df=sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
avg_age=round(df['age'].mean())
print(avg_age)
# Out:
# 30

# %%
df['age']=df['age'].fillna(avg_age)
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df=df.dropna(subset=['embarked'])
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         0
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      0
# alive            0
# alone            0
# dtype: int64

# %%
df['survived'].value_counts()
# Out:
# survived
# 0    549
# 1    340
# Name: count, dtype: int64

# %%
df['embark_town'].value_counts()
# Out:
# embark_town
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: count, dtype: int64

# %%
df['embark_town'].value_counts().idxmax()
# Out:
# 'Southampton'

# %%
df['embark_town'].value_counts().idxmin()
# Out:
# 'Queenstown'
